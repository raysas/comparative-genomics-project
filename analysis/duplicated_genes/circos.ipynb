# %%
import pandas as pd
from dash import Dash, html
import dash_bio as dashbio

# Load your CSV
df = pd.read_csv("../../output/statistics/duplicated_genes_info.csv")

# Prepare data for Circos
circos_data = []
for _, row in df.iterrows():
    circos_data.append({
        'block_id': str(row['chromosome']),    # chromosome segment
        'start': row['start_pos'],
        'end': row['end_pos'],
        'name': row['gene_id'],               # label
        'color': '#1f77b4'                    # any color
    })

# Prepare layout (chromosome sizes are approximated here)
chrom_sizes = df.groupby('chromosome')['end_pos'].max().to_dict()
layout = []
for chrom, size in chrom_sizes.items():
    layout.append({
        'id': str(chrom),
        'label': f'Chr{chrom}',
        'color': '#dddddd',
        'len': size
    })

# Initialize Dash app
app = Dash(__name__)

app.layout = html.Div([
    dashbio.Circos(
        id='genome-circos',
        layout=layout,
        tracks=[{
            'type': 'CHORDS',  # CHORDS if you have links, else 'HIGHLIGHT'
            'data': circos_data
        }],
        size=600
    )
])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 3
#       1 import pandas as pd
#       2 from dash import Dash, html
# ----> 3 import dash_bio as dashbio
#       5 # Load your CSV
#       6 df = pd.read_csv("../../output/statistics/duplicated_genes_info.csv")
#
# File ~/miniconda3/lib/python3.13/site-packages/dash_bio/__init__.py:28
#      25 package_name = package['name'].replace(' ', '_').replace('-', '_')
#      26 __version__ = package['version']
# ---> 28 from . import utils  # noqa: F401,E402
#      29 from ._imports_ import *  # noqa: F401, F403, E402
#      30 from ._imports_ import __all__  # noqa: E402
#
# File ~/miniconda3/lib/python3.13/site-packages/dash_bio/utils/__init__.py:1
# ----> 1 from .pdb_parser import PdbParser  # noqa: F401,E402
#       2 from .mol3dviewer_styles_creator import create_mol3d_style  # noqa: F401,E402
#       3 from .chem_structure_reader import read_chem_structure  # noqa: F401,E402
#
# File ~/miniconda3/lib/python3.13/site-packages/dash_bio/utils/pdb_parser.py:7
#       1 """PDB parser
#       2
#       3 This module contains a class that can read PDB files and return a dictionary of structural data"""
#       5 import re
# ----> 7 import parmed as pmd
#      10 class PdbParser:
#      11     """
#      12     Parse the protein data bank (PDB) file to generate
#      13     input data for Molecule3dViewer, Molecule2dViewer and Speck components.
#    (...)     16     Path to PDB file (either HTTP or local path).
#      17     """
#
# File ~/miniconda3/lib/python3.13/site-packages/parmed/__init__.py:23
#      21 from .topologyobjects import *
#      22 from .structure import Structure, StructureView
# ---> 23 from . import amber, charmm, gromacs, dlpoly, namd, openmm, rosetta, tinker, entos
#      24 from . import formats
#      25 from .vec3 import Vec3
#
# File ~/miniconda3/lib/python3.13/site-packages/parmed/amber/__init__.py:14
#      12 from .asciicrd import AmberAsciiRestart, AmberMdcrd
#      13 from .mask import AmberMask
# ---> 14 from .netcdffiles import NetCDFTraj, NetCDFRestart
#      15 from .offlib import AmberOFFLibrary
#      16 from .parameters import AmberParameterSet
#
# File ~/miniconda3/lib/python3.13/site-packages/parmed/amber/netcdffiles.py:25
#      23 from ..formats.registry import FileFormatType
#      24 from .. import unit as u
# ---> 25 from ..utils.netcdf import netcdf_file as NetCDFFile
#      26 import warnings
#      28 class NetCDFRestart(metaclass=FileFormatType):
#
# File ~/miniconda3/lib/python3.13/site-packages/parmed/utils/netcdf.py:46
#      43 import mmap as mm
#      45 import numpy as np
# ---> 46 from numpy.compat import asbytes, asstr
#      47 from numpy import frombuffer, dtype, empty, array, asarray
#      48 from numpy import little_endian as LITTLE_ENDIAN
#
# ModuleNotFoundError: No module named 'numpy.compat'
